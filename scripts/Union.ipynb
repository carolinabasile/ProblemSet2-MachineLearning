# %% [markdown]
# ## Unión de bases de datos

# %%
# Importo librerías

import os
import pandas as pd
from getpass import getpass
import subprocess
from zipfile import ZipFile
import shutil

# %%
# Elimino las carpetas necesarias para no duplicar el repositorio
folder_to_delete = "/content/ProblemSet2-MachineLearning"

if os.path.exists(folder_to_delete):
    shutil.rmtree(folder_to_delete)
    print(f"Deleted folder: {folder_to_delete}")
else:
    print("Folder does not exist.")
# Out:
# Deleted folder: /content/ProblemSet2-MachineLearning

# %%
# Clono el repositorio y accedo a la carpeta con las bases comprimidas

# !git clone https://github.com/carolinabasile/ProblemSet2-MachineLearning.git

# %cd /content/ProblemSet2-MachineLearning/stores/input
# Out:
# Cloning into 'ProblemSet2-MachineLearning'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 60 (delta 23), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 30.86 MiB | 12.74 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/ProblemSet2-MachineLearning/stores/input

# %%
# Descomprimo las bases
for file in os.listdir():
    if file.endswith('.rar'):
        # !unrar x {file}


# Leo las bases
dataframes = {}

for csv_file in os.listdir():
    if csv_file.endswith('.csv'):
        df = pd.read_csv(csv_file)
        dataframes[csv_file] = df
        print(csv_file)

train_personas = dataframes['train_personas.csv']
test_personas = dataframes['test_personas.csv']
train_hogares = dataframes['train_hogares.csv']
test_hogares = dataframes['test_hogares.csv']
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from train_hogares.rar
#
#   OK
#
# Would you like to replace the existing file test_personas.rar
# 4853094 bytes, modified on 2024-12-12 23:45
# with a new one
# 4853094 bytes, modified on 2024-12-11 11:28
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit Y
#
#   OK
#
# Would you like to replace the existing file test_hogares.rar
# 2335450 bytes, modified on 2024-12-12 23:45
# with a new one
# 2335450 bytes, modified on 2024-12-11 11:28
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit Y
#
#   OK
# All OK
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from train_personas.rar
#
#   OK
# All OK
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from test_personas.rar
#
#   OK
# All OK
#
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from test_hogares.rar
#
#   OK
# ...

# %%
# Uno las bases de hogares con las de individuos
train_df = pd.merge(train_hogares, train_personas, on='id', how='inner')

test_df = pd.merge(test_hogares, test_personas, on='id', how='inner')

# %%
train_df.head()
# Out:
#                          id  Clase_x Dominio_x  P5000  P5010  P5090  P5100  \
# 0  8d0193e328305a042001a35f        1  MEDELLIN      4      2      1    NaN
# 1  8d0193e328305a042001a35f        1  MEDELLIN      4      2      1    NaN
# 2  8d0193e328305a042001a35f        1  MEDELLIN      4      2      1    NaN
# 3  8d0193e328305a042001a35f        1  MEDELLIN      4      2      1    NaN
# 4  8d0193e328305a042001a35f        1  MEDELLIN      4      2      1    NaN
#
#       P5130  P5140  Nper  ...  Iof2es  Iof3hes  Iof3ies  Iof6es      Ingtotob  \
# 0  400000.0    NaN     5  ...     NaN      NaN      NaN     NaN  1.109190e+06
# 1  400000.0    NaN     5  ...     NaN      NaN      NaN     NaN           NaN
# 2  400000.0    NaN     5  ...     NaN      NaN      NaN     NaN  1.399140e+06
# 3  400000.0    NaN     5  ...     NaN      NaN      NaN     NaN           NaN
# 4  400000.0    NaN     5  ...     NaN      NaN      NaN     NaN           NaN
#
# ...

# %%
test_df.head()
# Out:
#                          id  Clase_x    Dominio_x  P5000  P5010  P5090  P5100  \
# 0  2a7ddc2779480d7f19834953        1  SANTA MARTA      4      3      1    NaN
# 1  2a7ddc2779480d7f19834953        1  SANTA MARTA      4      3      1    NaN
# 2  2a7ddc2779480d7f19834953        1  SANTA MARTA      4      3      1    NaN
# 3  2a7ddc2779480d7f19834953        1  SANTA MARTA      4      3      1    NaN
# 4  2a7ddc2779480d7f19834953        1  SANTA MARTA      4      3      1    NaN
#
#       P5130  P5140  Nper  ...  P7510s5  P7510s6  P7510s7  Pet   Oc  Des  Ina  \
# 0  400000.0    NaN     5  ...      NaN      NaN      NaN  1.0  1.0  NaN  NaN
# 1  400000.0    NaN     5  ...      NaN      NaN      NaN  1.0  1.0  NaN  NaN
# 2  400000.0    NaN     5  ...      NaN      NaN      NaN  1.0  NaN  NaN  1.0
# 3  400000.0    NaN     5  ...      NaN      NaN      NaN  1.0  NaN  1.0  NaN
# 4  400000.0    NaN     5  ...      NaN      NaN      NaN  1.0  NaN  NaN  1.0
#
#     Fex_c_y Depto_y  Fex_dpto_y
# ...

# %%
# Convierto las bases unidas a .csv

train_df.to_csv('/content/ProblemSet2-MachineLearning/stores/input/train_df.csv', index=False)
test_df.to_csv('/content/ProblemSet2-MachineLearning/stores/input/test_df.csv', index=False)

# %%
#  Comprimo las bases unidas para poder exportarlas al repositorio

train_file = '/content/ProblemSet2-MachineLearning/stores/input/train_df.csv'
test_file = '/content/ProblemSet2-MachineLearning/stores/input/test_df.csv'
train_zip = '/content/ProblemSet2-MachineLearning/stores/train_df.zip'
test_zip = '/content/ProblemSet2-MachineLearning/stores/test_df.zip'

with ZipFile(train_zip, 'w') as zipf:
    zipf.write(train_file)
print(f"Created zip file: {train_zip}")

with ZipFile(test_zip, 'w') as zipf:
    zipf.write(test_file)
print(f"Created zip file: {test_zip}")
# Out:
# Created zip file: /content/ProblemSet2-MachineLearning/stores/train_df.zip
# Created zip file: /content/ProblemSet2-MachineLearning/stores/test_df.zip

# %%
# !git config --global user.email "carolina.belen2527@gmail.com"
# !git config --global user.name "carolinabasile"

# %%
# Defino el path de mi repositorio en GitHub
repo_path = "/content/ProblemSet2-MachineLearning"
os.chdir(repo_path)

# Instalo librerías necesarias para exportar las bases a Github
# !apt-get install git-lfs -y
# !git lfs install

# Detecto las bases a exportar
# !git lfs track "*.zip"
# !git add .gitattributes

# Add y commit los archivos zip
# !git add {train_zip} {test_zip}
# !git commit -m "Add zipped train_df and test_df"

# Defino usuario y token para acceder al repositorio
TOKEN = "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"
GITHUB_USER = "carolinabasile"
REPO_NAME = "ProblemSet2-MachineLearning"

repo_url = f"https://{GITHUB_USER}:{TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"
# !git remote set-url origin {repo_url}

# Push los cambios al repositorio
# !git push origin main
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Updated git hooks.
# Git LFS initialized.
# Tracking "*.zip"
# [main 4435596] Add zipped train_df and test_df
#  3 files changed, 7 insertions(+)
#  create mode 100644 stores/test_df.zip
#  create mode 100644 stores/train_df.zip
# batch response: This repository is over its data quota. Account responsible for LFS bandwidth should purchase more data packs to restore access.
# error: failed to push some refs to 'https://github.com/carolinabasile/ProblemSet2-MachineLearning.git'
